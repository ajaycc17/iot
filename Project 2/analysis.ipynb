# %% [markdown]
# #### Ajay Choudhury (18018) EECS Dept.(2018)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("weather_data_2sites-1.csv") # read the .csv file
df.head()
# Out:
#    Unnamed: 0            timestamp  temperature_site1  humidity_site1  \
# 0           0  2018-03-01 00:00:00                NaN             NaN
# 1           1  2018-03-01 00:30:00               21.0            68.0
# 2           2  2018-03-01 01:00:00               20.0            73.0
# 3           3  2018-03-01 01:30:00               20.0            73.0
# 4           4  2018-03-01 02:00:00               20.0            73.0
#
#    temperature_site2  humidity_site2
# 0               23.1            61.6
# 1               22.9            61.1
# 2               23.0            61.6
# 3               22.9            62.5
# 4               22.4            63.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5780 entries, 0 to 5779
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5780 non-null   int64
#  1   timestamp          5780 non-null   object
#  2   temperature_site1  5779 non-null   float64
#  3   humidity_site1     5779 non-null   float64
#  4   temperature_site2  5780 non-null   float64
#  5   humidity_site2     5780 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 271.1+ KB

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5780 entries, 0 to 5779
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5780 non-null   int64
#  1   timestamp          5780 non-null   datetime64[ns]
#  2   temperature_site1  5779 non-null   float64
#  3   humidity_site1     5779 non-null   float64
#  4   temperature_site2  5780 non-null   float64
#  5   humidity_site2     5780 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 271.1 KB

# %%
df
# Out:
#       Unnamed: 0           timestamp  temperature_site1  humidity_site1  \
# 0              0 2018-03-01 00:00:00                NaN             NaN
# 1              1 2018-03-01 00:30:00               21.0            68.0
# 2              2 2018-03-01 01:00:00               20.0            73.0
# 3              3 2018-03-01 01:30:00               20.0            73.0
# 4              4 2018-03-01 02:00:00               20.0            73.0
# ...          ...                 ...                ...             ...
# 5775        5775 2018-06-29 01:00:00               28.0            84.0
# 5776        5776 2018-06-29 01:30:00               28.0            84.0
# 5777        5777 2018-06-29 02:00:00               28.0            84.0
# 5778        5778 2018-06-29 02:30:00               28.0            84.0
# 5779        5779 2018-06-29 03:00:00               28.0            84.0
#
#       temperature_site2  humidity_site2
# 0                  23.1            61.6
# 1                  22.9            61.1
# 2                  23.0            61.6
# 3                  22.9            62.5
# 4                  22.4            63.4
# ...                 ...             ...
# 5775               31.1            67.2
# 5776               31.1            67.2
# 5777               31.1            67.2
# 5778               31.1            67.2
# 5779               31.1            67.2
#
# [5780 rows x 6 columns]

# %%
df.sort_values(by='timestamp', inplace=True)
df
# Out:
#       Unnamed: 0           timestamp  temperature_site1  humidity_site1  \
# 0              0 2018-03-01 00:00:00                NaN             NaN
# 1              1 2018-03-01 00:30:00               21.0            68.0
# 2              2 2018-03-01 01:00:00               20.0            73.0
# 3              3 2018-03-01 01:30:00               20.0            73.0
# 4              4 2018-03-01 02:00:00               20.0            73.0
# ...          ...                 ...                ...             ...
# 5775        5775 2018-06-29 01:00:00               28.0            84.0
# 5776        5776 2018-06-29 01:30:00               28.0            84.0
# 5777        5777 2018-06-29 02:00:00               28.0            84.0
# 5778        5778 2018-06-29 02:30:00               28.0            84.0
# 5779        5779 2018-06-29 03:00:00               28.0            84.0
#
#       temperature_site2  humidity_site2
# 0                  23.1            61.6
# 1                  22.9            61.1
# 2                  23.0            61.6
# 3                  22.9            62.5
# 4                  22.4            63.4
# ...                 ...             ...
# 5775               31.1            67.2
# 5776               31.1            67.2
# 5777               31.1            67.2
# 5778               31.1            67.2
# 5779               31.1            67.2
#
# [5780 rows x 6 columns]

# %%
df1 = df.copy()
df1
# Out:
#       Unnamed: 0           timestamp  temperature_site1  humidity_site1  \
# 0              0 2018-03-01 00:00:00                NaN             NaN
# 1              1 2018-03-01 00:30:00               21.0            68.0
# 2              2 2018-03-01 01:00:00               20.0            73.0
# 3              3 2018-03-01 01:30:00               20.0            73.0
# 4              4 2018-03-01 02:00:00               20.0            73.0
# ...          ...                 ...                ...             ...
# 5775        5775 2018-06-29 01:00:00               28.0            84.0
# 5776        5776 2018-06-29 01:30:00               28.0            84.0
# 5777        5777 2018-06-29 02:00:00               28.0            84.0
# 5778        5778 2018-06-29 02:30:00               28.0            84.0
# 5779        5779 2018-06-29 03:00:00               28.0            84.0
#
#       temperature_site2  humidity_site2
# 0                  23.1            61.6
# 1                  22.9            61.1
# 2                  23.0            61.6
# 3                  22.9            62.5
# 4                  22.4            63.4
# ...                 ...             ...
# 5775               31.1            67.2
# 5776               31.1            67.2
# 5777               31.1            67.2
# 5778               31.1            67.2
# 5779               31.1            67.2
#
# [5780 rows x 6 columns]

# %%
df1 = df1.dropna(axis = 0, how ='any')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5779 entries, 1 to 5779
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5779 non-null   int64
#  1   timestamp          5779 non-null   datetime64[ns]
#  2   temperature_site1  5779 non-null   float64
#  3   humidity_site1     5779 non-null   float64
#  4   temperature_site2  5779 non-null   float64
#  5   humidity_site2     5779 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 316.0 KB

# %%
df1
# Out:
#       Unnamed: 0           timestamp  temperature_site1  humidity_site1  \
# 1              1 2018-03-01 00:30:00               21.0            68.0
# 2              2 2018-03-01 01:00:00               20.0            73.0
# 3              3 2018-03-01 01:30:00               20.0            73.0
# 4              4 2018-03-01 02:00:00               20.0            73.0
# 5              5 2018-03-01 02:30:00               20.0            70.0
# ...          ...                 ...                ...             ...
# 5775        5775 2018-06-29 01:00:00               28.0            84.0
# 5776        5776 2018-06-29 01:30:00               28.0            84.0
# 5777        5777 2018-06-29 02:00:00               28.0            84.0
# 5778        5778 2018-06-29 02:30:00               28.0            84.0
# 5779        5779 2018-06-29 03:00:00               28.0            84.0
#
#       temperature_site2  humidity_site2
# 1                  22.9            61.1
# 2                  23.0            61.6
# 3                  22.9            62.5
# 4                  22.4            63.4
# 5                  22.0            63.8
# ...                 ...             ...
# 5775               31.1            67.2
# 5776               31.1            67.2
# 5777               31.1            67.2
# 5778               31.1            67.2
# 5779               31.1            67.2
#
# [5779 rows x 6 columns]

# %%
import datetime

# my roll no.: 18018
# starting date = (1+8+1) = 10 to 14 (5 days)
# chosen month = March(3)
df1 = df1.set_index(['timestamp'])
df1 = df1.loc['2018-3-10':'2018-3-14']
df1
# Out:
#                      Unnamed: 0  temperature_site1  humidity_site1  \
# timestamp
# 2018-03-10 00:00:00         434               23.0            53.0
# 2018-03-10 00:30:00         435               22.0            57.0
# 2018-03-10 01:00:00         436               22.0            57.0
# 2018-03-10 01:30:00         437               22.0            57.0
# 2018-03-10 02:00:00         438               21.0            60.0
# ...                         ...                ...             ...
# 2018-03-14 21:30:00         669               27.0            34.0
# 2018-03-14 22:00:00         670               27.0            32.0
# 2018-03-14 22:30:00         671               26.0            36.0
# 2018-03-14 23:00:00         672               24.0            40.0
# 2018-03-14 23:30:00         673               22.0            44.0
#
#                      temperature_site2  humidity_site2
# timestamp
# 2018-03-10 00:00:00               25.0            51.5
# 2018-03-10 00:30:00               25.0            50.5
# 2018-03-10 01:00:00               24.7            50.4
# 2018-03-10 01:30:00               24.6            51.5
# 2018-03-10 02:00:00               24.0            52.4
# ...                                ...             ...
# 2018-03-14 21:30:00               28.6            37.5
# 2018-03-14 22:00:00               28.5            38.0
# 2018-03-14 22:30:00               28.0            40.7
# 2018-03-14 23:00:00               27.7            42.3
# 2018-03-14 23:30:00               27.2            43.4
#
# [240 rows x 5 columns]

# %%
df1.drop(['temperature_site2', 'humidity_site2'], axis=1, inplace= True)
df1
# Out:
#                      Unnamed: 0  temperature_site1  humidity_site1
# timestamp
# 2018-03-10 00:00:00         434               23.0            53.0
# 2018-03-10 00:30:00         435               22.0            57.0
# 2018-03-10 01:00:00         436               22.0            57.0
# 2018-03-10 01:30:00         437               22.0            57.0
# 2018-03-10 02:00:00         438               21.0            60.0
# ...                         ...                ...             ...
# 2018-03-14 21:30:00         669               27.0            34.0
# 2018-03-14 22:00:00         670               27.0            32.0
# 2018-03-14 22:30:00         671               26.0            36.0
# 2018-03-14 23:00:00         672               24.0            40.0
# 2018-03-14 23:30:00         673               22.0            44.0
#
# [240 rows x 3 columns]

# %%
df1.drop(df1.columns[df1.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df1
# Out:
#                      temperature_site1  humidity_site1
# timestamp
# 2018-03-10 00:00:00               23.0            53.0
# 2018-03-10 00:30:00               22.0            57.0
# 2018-03-10 01:00:00               22.0            57.0
# 2018-03-10 01:30:00               22.0            57.0
# 2018-03-10 02:00:00               21.0            60.0
# ...                                ...             ...
# 2018-03-14 21:30:00               27.0            34.0
# 2018-03-14 22:00:00               27.0            32.0
# 2018-03-14 22:30:00               26.0            36.0
# 2018-03-14 23:00:00               24.0            40.0
# 2018-03-14 23:30:00               22.0            44.0
#
# [240 rows x 2 columns]

# %%
df2 = df1.copy()
df2.reset_index(inplace = True)
df2['time'] = df2['timestamp'].dt.time
df2['month_day'] = df2['timestamp'].dt.day
df2
# Out:
#               timestamp  temperature_site1  humidity_site1      time  \
# 0   2018-03-10 00:00:00               23.0            53.0  00:00:00
# 1   2018-03-10 00:30:00               22.0            57.0  00:30:00
# 2   2018-03-10 01:00:00               22.0            57.0  01:00:00
# 3   2018-03-10 01:30:00               22.0            57.0  01:30:00
# 4   2018-03-10 02:00:00               21.0            60.0  02:00:00
# ..                  ...                ...             ...       ...
# 235 2018-03-14 21:30:00               27.0            34.0  21:30:00
# 236 2018-03-14 22:00:00               27.0            32.0  22:00:00
# 237 2018-03-14 22:30:00               26.0            36.0  22:30:00
# 238 2018-03-14 23:00:00               24.0            40.0  23:00:00
# 239 2018-03-14 23:30:00               22.0            44.0  23:30:00
#
#      month_day
# 0           10
# 1           10
# 2           10
# 3           10
# 4           10
# ..         ...
# 235         14
# 236         14
# 237         14
# 238         14
# 239         14
#
# [240 rows x 5 columns]

# %%
df2.drop(['timestamp'], axis=1, inplace= True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature_site1  240 non-null    float64
#  1   humidity_site1     240 non-null    float64
#  2   time               240 non-null    object
#  3   month_day          240 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 7.6+ KB

# %%
plt.rcParams["figure.figsize"] = [15.00, 6.00]

(df2.pivot(index='time', columns='month_day', values='temperature_site1')).plot()

plt.locator_params(axis='x', nbins=24)
plt.locator_params(axis='y', nbins=15)
plt.grid()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15.00, 6.00]

(df2.pivot(index='time', columns='month_day', values='humidity_site1')).plot()
plt.locator_params(axis='x', nbins=24)
plt.locator_params(axis='y', nbins=15)
plt.grid()
plt.show()

# %%
df2.boxplot(by ='month_day', column =['humidity_site1'], grid = False)
plt.show()

# %%
df2.boxplot(by ='month_day', column =['temperature_site1'], grid = False)
plt.show()

# %%
df3 = df2.copy()
df3 = df3.set_index(['month_day'])
df3 = df3.loc['10':'12']
df3
# Out:
#            temperature_site1  humidity_site1      time
# month_day
# 10                      23.0            53.0  00:00:00
# 10                      22.0            57.0  00:30:00
# 10                      22.0            57.0  01:00:00
# 10                      22.0            57.0  01:30:00
# 10                      21.0            60.0  02:00:00
# ...                      ...             ...       ...
# 12                      25.0            41.0  21:30:00
# 12                      25.0            44.0  22:00:00
# 12                      25.0            47.0  22:30:00
# 12                      25.0            47.0  23:00:00
# 12                      23.0            62.0  23:30:00
#
# [144 rows x 3 columns]

# %%
df3.reset_index(inplace = True)
df3
# Out:
#      month_day  temperature_site1  humidity_site1      time
# 0           10               23.0            53.0  00:00:00
# 1           10               22.0            57.0  00:30:00
# 2           10               22.0            57.0  01:00:00
# 3           10               22.0            57.0  01:30:00
# 4           10               21.0            60.0  02:00:00
# ..         ...                ...             ...       ...
# 139         12               25.0            41.0  21:30:00
# 140         12               25.0            44.0  22:00:00
# 141         12               25.0            47.0  22:30:00
# 142         12               25.0            47.0  23:00:00
# 143         12               23.0            62.0  23:30:00
#
# [144 rows x 4 columns]

# %%
df3.loc[df3['month_day'] == 10, 'temperature day10'] = df3['temperature_site1']
df3.loc[df3['month_day'] == 10, 'humidity day10'] = df3['humidity_site1']
df3.loc[df3['month_day'] == 11, 'temperature day11'] = df3['temperature_site1']
df3.loc[df3['month_day'] == 11, 'humidity day11'] = df3['humidity_site1']
df3.loc[df3['month_day'] == 12, 'temperature day12'] = df3['temperature_site1']
df3.loc[df3['month_day'] == 12, 'humidity day12'] = df3['humidity_site1']
df3
# Out:
#      month_day  temperature_site1  humidity_site1      time  \
# 0           10               23.0            53.0  00:00:00
# 1           10               22.0            57.0  00:30:00
# 2           10               22.0            57.0  01:00:00
# 3           10               22.0            57.0  01:30:00
# 4           10               21.0            60.0  02:00:00
# ..         ...                ...             ...       ...
# 139         12               25.0            41.0  21:30:00
# 140         12               25.0            44.0  22:00:00
# 141         12               25.0            47.0  22:30:00
# 142         12               25.0            47.0  23:00:00
# 143         12               23.0            62.0  23:30:00
#
#      temperature day10  humidity day10  temperature day11  humidity day11  \
# 0                 23.0            53.0                NaN             NaN
# 1                 22.0            57.0                NaN             NaN
# 2                 22.0            57.0                NaN             NaN
# 3                 22.0            57.0                NaN             NaN
# 4                 21.0            60.0                NaN             NaN
# ..                 ...             ...                ...             ...
# 139                NaN             NaN                NaN             NaN
# 140                NaN             NaN                NaN             NaN
# 141                NaN             NaN                NaN             NaN
# 142                NaN             NaN                NaN             NaN
# 143                NaN             NaN                NaN             NaN
#
#      temperature day12  humidity day12
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# ..                 ...             ...
# 139               25.0            41.0
# 140               25.0            44.0
# 141               25.0            47.0
# 142               25.0            47.0
# 143               23.0            62.0
#
# [144 rows x 10 columns]

# %%
df3.drop(['month_day', 'temperature_site1', 'humidity_site1', 'time'], axis=1, inplace= True)

# %%
df3
# Out:
#      temperature day10  humidity day10  temperature day11  humidity day11  \
# 0                 23.0            53.0                NaN             NaN
# 1                 22.0            57.0                NaN             NaN
# 2                 22.0            57.0                NaN             NaN
# 3                 22.0            57.0                NaN             NaN
# 4                 21.0            60.0                NaN             NaN
# ..                 ...             ...                ...             ...
# 139                NaN             NaN                NaN             NaN
# 140                NaN             NaN                NaN             NaN
# 141                NaN             NaN                NaN             NaN
# 142                NaN             NaN                NaN             NaN
# 143                NaN             NaN                NaN             NaN
#
#      temperature day12  humidity day12
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# ..                 ...             ...
# 139               25.0            41.0
# 140               25.0            44.0
# 141               25.0            47.0
# 142               25.0            47.0
# 143               23.0            62.0
#
# [144 rows x 6 columns]

# %%
def justify(a, invalid_val=0, axis=1, side='left'):
    if invalid_val is np.nan:
        mask = ~np.isnan(a)
    else:
        mask = a!=invalid_val
    justified_mask = np.sort(mask,axis=axis)
    if (side=='up') | (side=='left'):
        justified_mask = np.flip(justified_mask,axis=axis)
    out = np.full(a.shape, invalid_val) 
    if axis==1:
        out[justified_mask] = a[mask]
    else:
        out.T[justified_mask.T] = a.T[mask.T]
    return out

# %%
arr = justify(df3.to_numpy(), invalid_val=np.NaN,axis=0)

df3 = pd.DataFrame(arr, columns=df3.columns, index=df3.index)

# %%
df3.dropna(how='all', inplace=True)
df3
# Out:
#     temperature day10  humidity day10  temperature day11  humidity day11  \
# 0                23.0            53.0               23.0            57.0
# 1                22.0            57.0               22.0            60.0
# 2                22.0            57.0               22.0            60.0
# 3                22.0            57.0               21.0            64.0
# 4                21.0            60.0               21.0            64.0
# 5                20.0            64.0               20.0            73.0
# 6                20.0            64.0               19.0            78.0
# 7                19.5            68.5               18.0            83.0
# 8                19.0            73.0               18.0            83.0
# 9                18.0            77.0               18.0            83.0
# 10               17.0            82.0               17.0            88.0
# 11               18.0            72.0               17.0            90.0
# 12               16.0            88.0               16.0            94.0
# 13               15.0            94.0               16.0            94.0
# 14               15.0            88.0               16.0            94.0
# 15               16.0            88.0               16.0            94.0
# 16               17.0            82.0               17.0            88.0
# 17               19.0            60.0               19.0            63.0
# 18               21.0            60.0               20.0            68.0
# 19               23.0            53.0               21.0            64.0
# 20               24.0            50.0               23.0            57.0
# 21               25.0            44.0               24.0            53.0
# 22               27.0            34.0               25.0            50.0
# 23               29.0            21.0               28.0            36.0
# 24               29.5            25.0               29.0            37.0
# 25               30.0            29.0               29.0            37.0
# 26               31.0            25.0               29.5            35.0
# 27               31.0            24.0               30.0            33.0
# 28               30.0            25.0               31.0            31.0
# 29               33.0            13.0               33.0            16.0
# 30               32.0            22.0               32.0            26.0
# 31               32.0            22.0               32.0            26.0
# 32               32.0            21.0               32.0            26.0
# 33               31.0            22.0               32.0            27.0
# 34               31.0            24.0               32.0            26.0
# 35               30.0            19.0               31.0            29.0
# 36               29.0            30.0               30.0            29.0
# 37               28.0            32.0               29.0            30.0
# 38               27.0            34.0               28.0            32.0
# 39               27.0            39.0               27.0            34.0
# 40               26.0            44.0               26.0            39.0
# 41               25.0            43.0               24.0            46.0
# 42               26.0            44.0               25.0            41.0
# 43               25.0            47.0               25.0            41.0
# 44               25.0            50.0               24.0            47.0
# 45               24.0            53.0               24.0            47.0
# 46               24.0            53.0               24.0            47.0
# 47               23.0            55.0               22.0            55.0
#
#     temperature day12  humidity day12
# 0                23.0            44.0
# 1                20.0            64.0
# 2                20.0            64.0
# 3                21.0            60.0
# 4                21.0            60.0
# 5                20.0            58.0
# 6                22.0            60.0
# 7                20.0            68.0
# 8                19.0            68.0
# 9                18.0            77.0
# 10               17.0            82.0
# 11               18.0            70.0
# 12               17.0            82.0
# 13               17.0            82.0
# 14               17.0            88.0
# 15               17.0            88.0
# 16               20.0            68.0
# 17               21.0            61.0
# 18               21.0            68.0
# 19               23.0            61.0
# 20               24.0            57.0
# 21               26.0            51.0
# 22               27.0            48.0
# 23               30.0            28.0
# 24               30.5            30.5
# 25               31.0            33.0
# 26               32.0            31.0
# 27               32.0            29.0
# 28               33.0            26.0
# 29               34.0            11.0
# 30               34.0            20.0
# 31               34.0            19.0
# 32               34.0            19.0
# 33               33.0            20.0
# 34               33.0            20.0
# 35               32.0            18.0
# 36               31.0            22.5
# 37               30.0            27.0
# 38               30.0            27.0
# 39               28.0            30.0
# 40               28.0            30.0
# 41               26.0            34.0
# 42               26.0            36.0
# 43               25.0            41.0
# 44               25.0            44.0
# 45               25.0            47.0
# 46               25.0            47.0
# 47               23.0            62.0

# %%
import seaborn as sns
sns.pairplot(df3, kind="reg", diag_kind="kde")

# %%
# part 2
df.dropna(axis=0, inplace=True)
df
# Out:
#       Unnamed: 0           timestamp  temperature_site1  humidity_site1  \
# 1              1 2018-03-01 00:30:00               21.0            68.0
# 2              2 2018-03-01 01:00:00               20.0            73.0
# 3              3 2018-03-01 01:30:00               20.0            73.0
# 4              4 2018-03-01 02:00:00               20.0            73.0
# 5              5 2018-03-01 02:30:00               20.0            70.0
# ...          ...                 ...                ...             ...
# 5775        5775 2018-06-29 01:00:00               28.0            84.0
# 5776        5776 2018-06-29 01:30:00               28.0            84.0
# 5777        5777 2018-06-29 02:00:00               28.0            84.0
# 5778        5778 2018-06-29 02:30:00               28.0            84.0
# 5779        5779 2018-06-29 03:00:00               28.0            84.0
#
#       temperature_site2  humidity_site2
# 1                  22.9            61.1
# 2                  23.0            61.6
# 3                  22.9            62.5
# 4                  22.4            63.4
# 5                  22.0            63.8
# ...                 ...             ...
# 5775               31.1            67.2
# 5776               31.1            67.2
# 5777               31.1            67.2
# 5778               31.1            67.2
# 5779               31.1            67.2
#
# [5779 rows x 6 columns]

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df['timestamp'] =  pd.to_datetime(df['timestamp'])

df['temperature'] = df['temperature_site1']
df['humidity'] = df['humidity_site1']
df['day-minutes'] = df['timestamp'].dt.minute
df['day-of-the-week'] = df['timestamp'].dt.dayofweek

df.loc[0, 'previous-temperature'] = 0
for i in range(1, len(df)):
    df.loc[i, 'previous-temperature'] = df.loc[i-1, 'temperature']

# %%
df.drop(['timestamp','temperature_site1', 'humidity_site1', 'temperature_site2', 'humidity_site2'], axis=1, inplace= True)

# %%
df['previous-temperature'] = df['previous-temperature'].fillna(0)

# %%
syn_weather = df.copy()
syn_weather
# Out:
#       temperature  humidity  day-minutes  day-of-the-week  \
# 1            21.0      68.0         30.0              3.0
# 2            20.0      73.0          0.0              3.0
# 3            20.0      73.0         30.0              3.0
# 4            20.0      73.0          0.0              3.0
# 5            20.0      70.0         30.0              3.0
# ...           ...       ...          ...              ...
# 5776         28.0      84.0         30.0              4.0
# 5777         28.0      84.0          0.0              4.0
# 5778         28.0      84.0         30.0              4.0
# 5779         28.0      84.0          0.0              4.0
# 0             NaN       NaN          NaN              NaN
#
#       previous-temperature
# 1                      0.0
# 2                     21.0
# 3                     20.0
# 4                     20.0
# 5                     20.0
# ...                    ...
# 5776                  28.0
# 5777                  28.0
# 5778                  28.0
# 5779                  28.0
# 0                      0.0
#
# [5780 rows x 5 columns]

# %%
syn_weather.dropna(inplace=True)
syn_weather
# Out:
#       temperature  humidity  day-minutes  day-of-the-week  \
# 1            21.0      68.0         30.0              3.0
# 2            20.0      73.0          0.0              3.0
# 3            20.0      73.0         30.0              3.0
# 4            20.0      73.0          0.0              3.0
# 5            20.0      70.0         30.0              3.0
# ...           ...       ...          ...              ...
# 5775         28.0      84.0          0.0              4.0
# 5776         28.0      84.0         30.0              4.0
# 5777         28.0      84.0          0.0              4.0
# 5778         28.0      84.0         30.0              4.0
# 5779         28.0      84.0          0.0              4.0
#
#       previous-temperature
# 1                      0.0
# 2                     21.0
# 3                     20.0
# 4                     20.0
# 5                     20.0
# ...                    ...
# 5775                  28.0
# 5776                  28.0
# 5777                  28.0
# 5778                  28.0
# 5779                  28.0
#
# [5779 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_set, test_set  = train_test_split(syn_weather, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 4623
# Rows in test set: 1156

# %%
trainer = train_set.drop("temperature", axis=1)
trainer_labels = train_set["temperature"].copy()

# %%
trainer.describe()
# Out:
#           humidity  day-minutes  day-of-the-week  previous-temperature
# count  4623.000000  4623.000000      4623.000000           4623.000000
# mean     39.645929    14.973394         3.000865             31.400418
# std      18.049129    15.002594         1.993607              6.361565
# min       4.000000     0.000000         0.000000              0.000000
# 25%      26.000000     0.000000         1.000000             27.000000
# 50%      38.000000     0.000000         3.000000             32.000000
# 75%      52.000000    30.000000         5.000000             36.000000
# max     100.000000    33.000000         6.000000             46.000000

# %%
from sklearn.linear_model import LinearRegression
M1 = LinearRegression()
M1.fit(trainer, trainer_labels)
# Out:
# LinearRegression()

# %%
some_data = trainer.iloc[:5]
some_labels = trainer_labels.iloc[:5]

M1.predict(some_data)
# Out:
# array([33.22640074, 21.17206722, 35.04899675, 37.88723099, 38.9576358 ])

# %%
list(some_labels)
# Out:
# [32.666666666666664, 21.0, 33.0, 37.0, 39.0]

# %%
from sklearn.metrics import mean_squared_error
predictions = M1.predict(trainer)
mse = mean_squared_error(trainer_labels, predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.9754396323594324

# %%
from sklearn.tree import DecisionTreeRegressor
M2 = DecisionTreeRegressor()
M2.fit(trainer, trainer_labels)

M2.predict(some_data)
# Out:
# array([32.66666667, 21.        , 33.        , 37.        , 39.        ])

# %%
from sklearn.metrics import mean_squared_error
predictions = M2.predict(trainer)
mse = mean_squared_error(trainer_labels, predictions)
rmse = np.sqrt(mse)

rmse
# Out:
# 0.30835415975170727

# %%
# 10-fold
from sklearn.model_selection import cross_val_score
values = cross_val_score(M2, trainer, trainer_labels, scoring="neg_mean_squared_error", cv=10)
rmse_values = np.sqrt(-values)

def print_values(values):
    print("Values:", values)
    print("RMSE Mean: ", values.mean())
    print("Standard deviation: ", values.std())

print_values(rmse_values)
# Out:
# Values: [1.2073821  1.20864299 1.26465278 1.25535259 1.18059048 1.39439206
#  1.22503384 1.26364391 1.25152381 1.2372364 ]
# RMSE Mean:  1.2488450964945617
# Standard deviation:  0.05513451590587787

# %%
# correlations
corr_matrix = syn_weather.corr()
corr_matrix['temperature'].sort_values(ascending=False)
# Out:
# temperature             1.000000
# previous-temperature    0.987323
# day-minutes            -0.003865
# day-of-the-week        -0.021720
# humidity               -0.702853
# Name: temperature, dtype: float64

# %%
# on test dataset
X_test = test_set.drop("temperature", axis=1)
Y_test = test_set["temperature"].copy()

M1_predictions = M1.predict(X_test)
M2_predictions = M2.predict(X_test)

M1_mse = mean_squared_error(Y_test, M1_predictions)
M2_mse = mean_squared_error(Y_test, M2_predictions)

M1_rmse = np.sqrt(M1_mse)
M2_rmse = np.sqrt(M2_mse)
# print(final_predictions, list(Y_test))

# %%
M1_rmse
# Out:
# 1.0453186614107852

# %%
M2_rmse
# Out:
# 1.3195173599352024

# %%
new_df = pd.DataFrame()
new_df['M1'] = M1_predictions
new_df['M2'] = M2_predictions
new_df['Actual'] = list(Y_test)

# %%
new_df
# Out:
#              M1    M2     Actual
# 0     26.001836  26.0  26.000000
# 1     34.945721  34.5  35.000000
# 2     25.761324  26.5  26.000000
# 3     36.469423  36.0  38.000000
# 4     19.198263  20.0  19.000000
# ...         ...   ...        ...
# 1151  31.809731  32.0  32.000000
# 1152  36.390005  38.0  35.666667
# 1153  16.092506  16.0  17.000000
# 1154  20.212890  20.0  19.000000
# 1155  31.566504  31.0  31.000000
#
# [1156 rows x 3 columns]

# %%
x1 = new_df['M1']
x2 = new_df['M2']
y = new_df['Actual']

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Model Predictions vs Actual temperature')
ax1.scatter(x1,y)
ax2.scatter(x2,y)

ax1.set(xlabel='M1 Predicted Temperature', ylabel='Actual temperature')
ax2.set(xlabel='M2 Predicted Temperature', ylabel='Actual temperature')
# Out:
# [Text(0.5, 0, 'M2 Predicted Temperature'), Text(0, 0.5, 'Actual temperature')]
